# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Egor Gavriushkin
# Data Scientist in medical field**

# %% [markdown]
# *I am interested in data science because I want to solve interesting medical tasks.*

# %% [markdown]
# ### My code calculates 1+1

# %%
1+1
# Out:
# 2

# %% [markdown]
# #### Not a header at all
# 1. Coursera Tools for Data Science
# 2. Week 3 and 4
# 3. Materials
# 4. >~~are gorgeus~~
# ---
# 5. >>~~While being amazing~~
# ---
# 6. >>>~~And very easy to understand~~
# ---
